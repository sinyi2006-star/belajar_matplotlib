# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.7
# 2.3.4

# %%
mu, sigma = 100, 15 

x = mu + sigma * np.random.randn(10000) 
x
# Out:
# array([119.66175587,  89.29816633,  87.42864724, ...,  83.56918858,
#        111.46535952, 104.47665147], shape=(10000,))

# %%
x.shape
# Out:
# (10000,)

# %%
plt.hist(x, 
         bins=50, 
         facecolor='g', 
         alpha=0.50)

plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Histogram')

plt.text(45, 500, '$\mu=100,\ \sigma=15$')
plt.grid()

plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19988\697759563.py:10: SyntaxWarning: invalid escape sequence '\m'
#   plt.text(45, 500, '$\mu=100,\ \sigma=15$')

# %%
fig, ax = plt.subplots()

ax.hist(x, 
        bins=50, 
        facecolor='b', 
        alpha=0.25)

ax.set_xlabel('Sumbu X')
ax.set_ylabel('Sumbu Y')
ax.set_title('Contoh Histogram')

ax.text(45, 500, '$\mu=100,\ \sigma=15$')
ax.grid()

plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19988\2059470046.py:12: SyntaxWarning: invalid escape sequence '\m'
#   ax.text(45, 500, '$\mu=100,\ \sigma=15$')
